# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# !pip install cartopy
# !pip install geoviews
# !pip install pyproj

# Import API key
geoapify_key = "33acfa98a829415c8b98befd78f900cc"
print(geoapify_key)
# Out:
# Collecting cartopy
#   Obtaining dependency information for cartopy from https://files.pythonhosted.org/packages/bb/50/ab5495dcc22587179134cd37e6534212babeda78e86bda311c37c773f086/Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\mcayt\anaconda3\lib\site-packages (from cartopy) (1.26.2)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\mcayt\anaconda3\lib\site-packages (from cartopy) (3.8.0)
# Collecting shapely>=1.7 (from cartopy)
#   Obtaining dependency information for shapely>=1.7 from https://files.pythonhosted.org/packages/9e/39/029c441d8af32ab423b229c4525ce5ce6707318155b59634811a4c56f5c4/shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: packaging>=20 in c:\users\mcayt\anaconda3\lib\site-packages (from cartopy) (23.1)
# Collecting pyshp>=2.1 (from cartopy)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      -------------------------- ------------- 30.7/46.5 kB ? eta -:--:--
#      ---------------------------------------- 46.5/46.5 kB 1.2 MB/s eta 0:00:00
# Collecting pyproj>=3.1.0 (from cartopy)
#   Obtaining dependency information for pyproj>=3.1.0 from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in c:\users\mcayt\anaconda3\lib\site-packages (from pyproj>=3.1.0->cartopy) (2023.11.17)
# Requirement already satisfied: six>=1.5 in c:\users\mcayt\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.2 MB 6.9 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.2 MB 11.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.3/11.2 MB 18.4 MB/s eta 0:00:01
#    -------------- ------------------------- 4.0/11.2 MB 21.1 MB/s eta 0:00:01
#    -------------------- ------------------- 5.6/11.2 MB 23.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.2/11.2 MB 25.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.2 MB 28.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.2 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.2 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 28.5 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    -------- ------------------------------- 1.2/6.1 MB 76.2 MB/s eta 0:00:01
#    --------------- ------------------------ 2.3/6.1 MB 29.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.1 MB 27.4 MB/s eta 0:00:01
#    ------------------------------------ --- 5.5/6.1 MB 31.9 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 32.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 27.8 MB/s eta 0:00:00
# Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 46.0 MB/s eta 0:00:00
# Installing collected packages: shapely, pyshp, pyproj, cartopy
# Successfully installed cartopy-0.22.0 pyproj-3.6.1 pyshp-2.3.1 shapely-2.0.2
# Collecting geoviews
#   Obtaining dependency information for geoviews from https://files.pythonhosted.org/packages/72/10/81aaca3edf7d7bfb14a9a17b5effaeb9dcba54ba9703b392bb17241e45ea/geoviews-1.11.0-py2.py3-none-any.whl.metadata
#   Downloading geoviews-1.11.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (3.3.0)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (1.18.1)
# Requirement already satisfied: packaging in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (23.1)
# Requirement already satisfied: numpy in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (1.26.2)
# Requirement already satisfied: shapely in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (2.0.2)
# Requirement already satisfied: param in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: panel>=1.0.0 in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (1.3.1)
# Requirement already satisfied: pyproj in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\mcayt\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\mcayt\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\mcayt\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\mcayt\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (2.1.4)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mcayt\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (10.0.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\mcayt\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\mcayt\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.3.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\mcayt\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.0)
# Requirement already satisfied: pyshp>=2.1 in c:\users\mcayt\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\mcayt\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.0)
# Requirement already satisfied: colorcet in c:\users\mcayt\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: markdown in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\mcayt\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: certifi in c:\users\mcayt\anaconda3\lib\site-packages (from pyproj->geoviews) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mcayt\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->geoviews) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mcayt\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mcayt\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mcayt\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\mcayt\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\mcayt\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\mcayt\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\mcayt\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\mcayt\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mcayt\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mcayt\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mcayt\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mcayt\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.18)
# Downloading geoviews-1.11.0-py2.py3-none-any.whl (511 kB)
#    ---------------------------------------- 0.0/511.2 kB ? eta -:--:--
#     --------------------------------------- 10.2/511.2 kB ? eta -:--:--
#    ---- ---------------------------------- 61.4/511.2 kB 812.7 kB/s eta 0:00:01
#    -------------------------------- ------- 409.6/511.2 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 511.2/511.2 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: geoviews
# Successfully installed geoviews-1.11.0
# Requirement already satisfied: pyproj in c:\users\mcayt\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: certifi in c:\users\mcayt\anaconda3\lib\site-packages (from pyproj) (2023.11.17)
# 33acfa98a829415c8b98befd78f900cc

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0         georgetown   5.4112  100.3354     26.96        69
# 1        1           hermanus -34.4187   19.2345     20.47        85
# 2        2  port-aux-francais -49.3500   70.2167      5.97        94
# 3        3            pangody  65.8500   74.4859    -26.87        94
# 4        4     puerto natales -51.7236  -72.4875     16.25        51
#
#    Cloudiness  Wind Speed Country        Date
# 0          20        3.60      MY  1705011181
# 1          81        2.91      ZA  1705011345
# 2         100       13.04      TF  1705011346
# 3          86        6.60      RU  1705011346
# 4          75        9.26      CL  1705011346

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1.0,
    color = "City"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
vacation_cities_df = city_data_df[(city_data_df["Humidity"]<= 70) & (city_data_df["Max Temp"] <= 27) & (city_data_df["Max Temp"] >= 20)]

# Drop any rows with null values
cleaned_vacation_cities_df = vacation_cities_df.dropna(subset=['Humidity', 'Max Temp'])

# Display sample data
cleaned_vacation_cities_df
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0          0           georgetown   5.4112  100.3354     26.96        69
# 40        40               ouadda   8.0777   22.4007     20.61        30
# 72        72       punta del este -34.9667  -54.9500     20.06        66
# 94        94              ad darb  17.7229   42.2526     24.81        65
# 126      126       cabo san lucas  22.8909 -109.9124     25.34        58
# 135      135              stawell -37.0500  142.7667     21.97        39
# 140      140        mount gambier -37.8333  140.7667     21.46        53
# 150      150         stephenville  32.2207  -98.2023     24.44        23
# 166      166             candolim  15.5181   73.7626     25.39        47
# 168      168     minas de marcona -15.2119  -75.1103     20.42        70
# 169      169               callao -12.0667  -77.1500     25.16        69
# 171      171         port lincoln -34.7333  135.8667     22.23        63
# 200      200             bathurst -33.4166  149.5806     24.98        66
# 205      205            porbandar  21.6422   69.6093     20.70        38
# 212      212        haiku-pauwela  20.9219 -156.3051     26.13        64
# 227      227                pisco -13.7000  -76.2167     25.03        69
# 232      232          nova sintra  14.8667  -24.7167     20.51        68
# 242      242            taoudenni  22.6783   -3.9836     20.12        10
# 259      259              tambura   5.6000   27.4667     24.39        32
# 290      290               paidha   2.4167   30.9855     21.59        40
# 297      297              sechura  -5.5569  -80.8222     26.26        67
# 302      302                 yeed   4.5500   43.0333     25.93        35
# 319      319                 boda   4.3189   17.4695     24.08        19
# 321      321               bentiu   9.2333   29.8333     25.46        29
# 349      349          new norfolk -42.7826  147.0587     20.95        54
# 356      356                  oyo   7.8500    3.9333     26.04        12
# 367      367                 raja   8.4596   25.6780     22.75        32
# 368      368          xaltianguis  17.0667  -99.8333     24.73        60
# 392      392                 tome -36.6167  -72.9500     20.34        60
# 395      395            tazacorte  28.6290  -17.9293     22.86        28
# 396      396              mukalla  14.5425   49.1242     21.67        69
# 399      399         san patricio  28.0170  -97.5169     26.20        59
# 404      404              pacocha -17.5833  -71.3333     23.08        69
# 417      417              zungeru   9.8128    6.1558     25.26         9
# 420      420            ratnagiri  16.9833   73.3000     24.96        48
# 421      421           concepcion -36.8270  -73.0498     20.89        56
# 448      448                zemio   5.0314   25.1361     23.38        33
# 451      451                crane  31.3974 -102.3501     20.17        11
# 464      464                 chui -33.6971  -53.4616     20.19        67
# 485      485               moyale   3.5167   39.0584     22.05        41
# 504      504               ixtapa  20.7000 -105.2000     24.57        69
# 524      524               medina  24.4686   39.6142     21.24        32
# 525      525              ban tak  17.0432   99.0813     20.12        55
# 528      528              gobabis -22.4500   18.9667     26.07        42
# 559      559               gaiman -43.2897  -65.4929     23.41        26
# 563      563             pimentel  -6.8367  -79.9342     26.16        69
# 566      566               rawson -43.3002  -65.1023     20.30        41
# 569      569  veinticinco de mayo -35.4323  -60.1727     23.88        45
# 591      591                 bage -31.3314  -54.1069     25.88        65
# 592      592      louis trichardt -23.0439   29.9032     23.02        65
#
#      Cloudiness  Wind Speed Country        Date
# 0            20        3.60      MY  1705011181
# 40           49        2.40      CF  1705011355
# 72           75        5.14      UY  1705011359
# 94            1        0.40      SA  1705011361
# 126          40        8.75      MX  1705010908
# 135           1        0.90      AU  1705011371
# 140           9        1.98      AU  1705011372
# 150           0        7.20      US  1705011375
# 166          44        3.67      IN  1705011378
# 168          38        6.88      PE  1705011378
# 169           0        8.23      PE  1705011330
# 171           0        2.73      AU  1705011379
# 200          58        0.89      AU  1705011386
# 205           0        4.34      IN  1705011388
# 212          40        9.77      US  1705011391
# 227           0        9.26      PE  1705011273
# 232          77        4.81      CV  1705011399
# 242          25        3.81      ML  1705011402
# 259          49        1.94      SS  1705011404
# 290          96        2.66      UG  1705011408
# 297          27        6.30      PE  1705011409
# 302           6        3.78      SO  1705011410
# 319          79        1.29      CF  1705011414
# 321          14        2.43      SS  1705011415
# 349          50        1.21      AU  1705011418
# 356          25        1.15      NG  1705011424
# 367          10        1.78      SS  1705011427
# 368          47        3.17      MX  1705011427
# 392           2        5.82      CL  1705011439
# 395           0        9.26      ES  1705011440
# 396          19        2.20      YE  1705011440
# 399           8        7.83      US  1705011440
# 404           0        3.09      PE  1705011442
# 417          89        2.76      NG  1705011449
# 420           4        2.30      IN  1705011450
# 421           0        7.72      CL  1705011374
# 448          18        1.53      CF  1705011456
# 451           0       11.54      US  1705011456
# 464          83        4.10      UY  1705011464
# 485           9        3.46      KE  1705011466
# 504         100        3.60      MX  1705011469
# 524           0        3.09      SA  1705011476
# 525           2        1.68      TH  1705011476
# 528          81        6.46     NaN  1705011477
# 559           3       12.68      AR  1705011481
# 563           0        6.69      PE  1705011482
# 566           8       10.89      AR  1705011483
# 569          10        1.79      AR  1705011484
# 591          20        6.17      BR  1705011490
# 592         100        2.05      ZA  1705011490

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = cleaned_vacation_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                     City Country      Lat       Lng  Humidity Hotel Name
# 0             georgetown      MY   5.4112  100.3354        69
# 40                ouadda      CF   8.0777   22.4007        30
# 72        punta del este      UY -34.9667  -54.9500        66
# 94               ad darb      SA  17.7229   42.2526        65
# 126       cabo san lucas      MX  22.8909 -109.9124        58
# 135              stawell      AU -37.0500  142.7667        39
# 140        mount gambier      AU -37.8333  140.7667        53
# 150         stephenville      US  32.2207  -98.2023        23
# 166             candolim      IN  15.5181   73.7626        47
# 168     minas de marcona      PE -15.2119  -75.1103        70
# 169               callao      PE -12.0667  -77.1500        69
# 171         port lincoln      AU -34.7333  135.8667        63
# 200             bathurst      AU -33.4166  149.5806        66
# 205            porbandar      IN  21.6422   69.6093        38
# 212        haiku-pauwela      US  20.9219 -156.3051        64
# 227                pisco      PE -13.7000  -76.2167        69
# 232          nova sintra      CV  14.8667  -24.7167        68
# 242            taoudenni      ML  22.6783   -3.9836        10
# 259              tambura      SS   5.6000   27.4667        32
# 290               paidha      UG   2.4167   30.9855        40
# 297              sechura      PE  -5.5569  -80.8222        67
# 302                 yeed      SO   4.5500   43.0333        35
# 319                 boda      CF   4.3189   17.4695        19
# 321               bentiu      SS   9.2333   29.8333        29
# 349          new norfolk      AU -42.7826  147.0587        54
# 356                  oyo      NG   7.8500    3.9333        12
# 367                 raja      SS   8.4596   25.6780        32
# 368          xaltianguis      MX  17.0667  -99.8333        60
# 392                 tome      CL -36.6167  -72.9500        60
# 395            tazacorte      ES  28.6290  -17.9293        28
# 396              mukalla      YE  14.5425   49.1242        69
# 399         san patricio      US  28.0170  -97.5169        59
# 404              pacocha      PE -17.5833  -71.3333        69
# 417              zungeru      NG   9.8128    6.1558         9
# 420            ratnagiri      IN  16.9833   73.3000        48
# 421           concepcion      CL -36.8270  -73.0498        56
# 448                zemio      CF   5.0314   25.1361        33
# 451                crane      US  31.3974 -102.3501        11
# 464                 chui      UY -33.6971  -53.4616        67
# 485               moyale      KE   3.5167   39.0584        41
# 504               ixtapa      MX  20.7000 -105.2000        69
# 524               medina      SA  24.4686   39.6142        32
# 525              ban tak      TH  17.0432   99.0813        55
# 528              gobabis     NaN -22.4500   18.9667        42
# 559               gaiman      AR -43.2897  -65.4929        26
# 563             pimentel      PE  -6.8367  -79.9342        69
# 566               rawson      AR -43.3002  -65.1023        41
# 569  veinticinco de mayo      AR -35.4323  -60.1727        45
# 591                 bage      BR -31.3314  -54.1069        65
# 592      louis trichardt      ZA -23.0439   29.9032        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
     # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    # name_address
    
    # Convert the API response to JSON format
    name_address_json = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address_json["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    # print(f"{name_address}")
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# georgetown - nearest hotel: Page 63 hostel
# ouadda - nearest hotel: No hotel found
# punta del este - nearest hotel: Hotel Aquarium
# ad darb - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: Comfort Rooms
# stawell - nearest hotel: Coorrabin Motor Inn
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# stephenville - nearest hotel: No hotel found
# candolim - nearest hotel: Silver Sands Holiday Village
# minas de marcona - nearest hotel: No hotel found
# callao - nearest hotel: Casa Ronald
# port lincoln - nearest hotel: Boston Hotel
# bathurst - nearest hotel: King's Hotel
# porbandar - nearest hotel: Toran Tourist Bungalow
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# pisco - nearest hotel: La Portada
# nova sintra - nearest hotel: Residência Ka Dencho
# taoudenni - nearest hotel: No hotel found
# tambura - nearest hotel: No hotel found
# paidha - nearest hotel: Jennifer
# sechura - nearest hotel: Maximus Inn
# yeed - nearest hotel: No hotel found
# boda - nearest hotel: No hotel found
# bentiu - nearest hotel: Peace Hotel
# new norfolk - nearest hotel: Woodbridge on the Derwent
# oyo - nearest hotel: No hotel found
# raja - nearest hotel: No hotel found
# xaltianguis - nearest hotel: No hotel found
# tome - nearest hotel: No hotel found
# tazacorte - nearest hotel: App Leyma
# mukalla - nearest hotel: فندق الجابري
# san patricio - nearest hotel: No hotel found
# pacocha - nearest hotel: Gran Hotel Ilo
# zungeru - nearest hotel: No hotel found
# ratnagiri - nearest hotel: Vihar
# concepcion - nearest hotel: Hotel One (ex-Biobio)
# zemio - nearest hotel: No hotel found
# crane - nearest hotel: No hotel found
# chui - nearest hotel: Alerces
# moyale - nearest hotel: Paul’s guest house
# ixtapa - nearest hotel: Ma. Cristina
# medina - nearest hotel: The Oberoi Madina
# ban tak - nearest hotel: Romruen Resort
# gobabis - nearest hotel: Kalahari Convention Centre Hotel
# gaiman - nearest hotel: yr hen ffordd
# pimentel - nearest hotel: Hospedaje Calle del Sol
# rawson - nearest hotel: Hotel Deportivo
# veinticinco de mayo - nearest hotel: Jorly
# bage - nearest hotel: hotel obino
# louis trichardt - nearest hotel: Clouds' End Hotel
#                     City Country      Lat       Lng  Humidity  \
# 0             georgetown      MY   5.4112  100.3354        69
# 40                ouadda      CF   8.0777   22.4007        30
# 72        punta del este      UY -34.9667  -54.9500        66
# 94               ad darb      SA  17.7229   42.2526        65
# 126       cabo san lucas      MX  22.8909 -109.9124        58
# 135              stawell      AU -37.0500  142.7667        39
# 140        mount gambier      AU -37.8333  140.7667        53
# 150         stephenville      US  32.2207  -98.2023        23
# 166             candolim      IN  15.5181   73.7626        47
# 168     minas de marcona      PE -15.2119  -75.1103        70
# 169               callao      PE -12.0667  -77.1500        69
# 171         port lincoln      AU -34.7333  135.8667        63
# 200             bathurst      AU -33.4166  149.5806        66
# 205            porbandar      IN  21.6422   69.6093        38
# 212        haiku-pauwela      US  20.9219 -156.3051        64
# 227                pisco      PE -13.7000  -76.2167        69
# 232          nova sintra      CV  14.8667  -24.7167        68
# 242            taoudenni      ML  22.6783   -3.9836        10
# 259              tambura      SS   5.6000   27.4667        32
# 290               paidha      UG   2.4167   30.9855        40
# 297              sechura      PE  -5.5569  -80.8222        67
# 302                 yeed      SO   4.5500   43.0333        35
# 319                 boda      CF   4.3189   17.4695        19
# 321               bentiu      SS   9.2333   29.8333        29
# 349          new norfolk      AU -42.7826  147.0587        54
# 356                  oyo      NG   7.8500    3.9333        12
# 367                 raja      SS   8.4596   25.6780        32
# 368          xaltianguis      MX  17.0667  -99.8333        60
# 392                 tome      CL -36.6167  -72.9500        60
# 395            tazacorte      ES  28.6290  -17.9293        28
# 396              mukalla      YE  14.5425   49.1242        69
# 399         san patricio      US  28.0170  -97.5169        59
# 404              pacocha      PE -17.5833  -71.3333        69
# 417              zungeru      NG   9.8128    6.1558         9
# 420            ratnagiri      IN  16.9833   73.3000        48
# 421           concepcion      CL -36.8270  -73.0498        56
# 448                zemio      CF   5.0314   25.1361        33
# 451                crane      US  31.3974 -102.3501        11
# 464                 chui      UY -33.6971  -53.4616        67
# 485               moyale      KE   3.5167   39.0584        41
# 504               ixtapa      MX  20.7000 -105.2000        69
# 524               medina      SA  24.4686   39.6142        32
# 525              ban tak      TH  17.0432   99.0813        55
# 528              gobabis     NaN -22.4500   18.9667        42
# 559               gaiman      AR -43.2897  -65.4929        26
# 563             pimentel      PE  -6.8367  -79.9342        69
# 566               rawson      AR -43.3002  -65.1023        41
# 569  veinticinco de mayo      AR -35.4323  -60.1727        45
# 591                 bage      BR -31.3314  -54.1069        65
# 592      louis trichardt      ZA -23.0439   29.9032        65
#
#                            Hotel Name
# 0                      Page 63 hostel
# 40                     No hotel found
# 72                     Hotel Aquarium
# 94                     No hotel found
# 126                     Comfort Rooms
# 135               Coorrabin Motor Inn
# 140        The Old Mount Gambier Gaol
# 150                    No hotel found
# 166      Silver Sands Holiday Village
# 168                    No hotel found
# 169                       Casa Ronald
# 171                      Boston Hotel
# 200                      King's Hotel
# 205            Toran Tourist Bungalow
# 212          Inn At Mama's Fish House
# 227                        La Portada
# 232              Residência Ka Dencho
# 242                    No hotel found
# 259                    No hotel found
# 290                          Jennifer
# 297                       Maximus Inn
# 302                    No hotel found
# 319                    No hotel found
# 321                       Peace Hotel
# 349         Woodbridge on the Derwent
# 356                    No hotel found
# 367                    No hotel found
# 368                    No hotel found
# 392                    No hotel found
# 395                         App Leyma
# 396                      فندق الجابري
# 399                    No hotel found
# 404                    Gran Hotel Ilo
# 417                    No hotel found
# 420                             Vihar
# 421             Hotel One (ex-Biobio)
# 448                    No hotel found
# 451                    No hotel found
# 464                           Alerces
# 485                Paul’s guest house
# 504                      Ma. Cristina
# 524                 The Oberoi Madina
# 525                    Romruen Resort
# 528  Kalahari Convention Centre Hotel
# 559                     yr hen ffordd
# 563           Hospedaje Calle del Sol
# 566                   Hotel Deportivo
# 569                             Jorly
# 591                       hotel obino
# 592                 Clouds' End Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
filtered_hotel_df = hotel_df[hotel_df['Hotel Name'] != "No hotel found"]
map_plot_2 = filtered_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=800,
    frame_height=600,
    size="Humidity",
    scale=1.0,
    color="City",
    hover_cols=['Hotel Name', 'City', 'Country']
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
